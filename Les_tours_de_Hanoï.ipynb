# %% [markdown]
# <a href="https://colab.research.google.com/github/GeoLabUniLaSalle/Python/blob/main/Les_tours_de_Hano%C3%AF.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Les tours de Hanoï**
#
# Voici un exercice qui vous permettra de vous exercer sur la pratique de la récursivité.
#
# Les tours de Hanoï sont un jeu de réflexion constitué de 3 piquets A, B, et C, et n disques de diamètres diffétents. Les disques sont percés en leur centre pour pouvoir être enfilés sur les 3 piquets.
#
# Initialement, les n disques sont placés par taille décroissante sur le piquet A (celui de gauche).
#
# ![Capture d’écran 2021-03-07 à 13.58.00.png](data:image/png;base64,...)
#
# Le but du jeu est de déplacer tous les disques sur le piquet C en un minimum de coups. Les déplacements doivent respecter un certain nombre de règles :
# *   On ne peut déplacer plus d'un disque à la fois
# *   on ne peut placer un disque que sur un autre disque plus grand que lui ou sur un emplacement vide
#
# Voici une solution sur un exemple à 3 disques :
#
# ![hanoi-2.png](data:image/png;base64,...)
#
# Ce problème peut être résolu de manière récursive avec le raisonnement suivant :
# *   On déplace n-1 disques de A vers la tour B
# *   On déplace le dernier disque de A vers C
# *   On déplace les n-1 disques de B vers C
#
# L'idée ici est de réaliser une fonction récursive qui prenne en paramètre le nombre de disques à déplacer, et le noms de 3 tours : la tour de départ, la tour intermédiaire, et la tour de fin.
#
# Voici l'en-tête de la fonction :
# `def hanoi(n,debut,inter,fin):`
#
# Lorsque l'on exécutera cette fonction, si on prend l'exemple résolu ci-dessus, on appellera :
# `hanoi(3,'A','B','C')`
#
# Lorsque l'on exécutera cette fonction, elle cherchera donc à déplacer n-1 disques de A vers B (premier point du raisonnement exposé ci-dessus). La fonction s'appellera alors elle-même avec n-1 disques en paramètre :
# `hanoi(2,'A','C','B')`
#
# Et ainsi de suite...
#
# Lorsque nous avons un seul disque à déplacer (condition d'arrêt), on affiche le déplacement réalisé sous la forme "A B" pour indiquer que l'on déplace un disque du piquet A vers le piquet B.
#
#
# Ecrivez ici la fonction hanoi :

# %%
def hanoi(n,debut,inter,fin):
