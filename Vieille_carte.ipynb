# %% [markdown]
# <a href="https://colab.research.google.com/github/GeoLabUniLaSalle/Python/blob/main/Vieille_carte.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Vieille carte ★★★**
#
#
#
#
# *Exercice disponible sur la plateforme TOSA : Battle Dev Hello Works - Novembre 2019 : https://www.isograd.com/FR/solutionconcours.php*
#
#
#
# **Enoncé**
#
#
# Vous avez réussi à vous procurer la carte ci-dessous montrant différents temples reliés par d'antiques lignes telluriques. Les noms (indiqués ici par des lettres de A à N) sont donnés dans une langue oubliée.
#
# ![Sans titre3.jpg](data:image/jpeg;base64,...)
#
# La carte donne aussi le nom du Temple Perdu. Comme il est fourni en langue oubliée, vous ne pouvez savoir où il se trouve dans le monde d'aujourd'hui. Mais heureusement, vous disposez d'une carte du même réseau, rédigée dans une langue plus récente. Il suffit d'identifier les temples de la carte récente avec les temples de la carte antique pour trouver le Temple Perdu !
#
#
# Votre travail est d'écrire un programme prenant en entrée la carte moderne et calculant pour chaque temple indiqué sur la carte à quel temple il correspond sur la carte ancienne et d'en déduire le nom actuel Temple Perdu dont vous connaissez le nom ancien.
#
#
#
#
# **Format des données**
#
# *Entrée*
#
# Ligne 1 : Une lettre entre A et N indiquant l'emplacement du temple perdu sur la vieille carte !
# Lignes 2 à 22 : deux chaines contenant entre 5 et 30 caractères alphabétiques séparées par un espace représentant les noms de deux temples connectés sur la nouvelle carte.
#
#
# *Sortie*
#
# Le nom, sur la nouvelle carte, du temple correspondant au temple perdu !
#
# *Exemple*
#
# A
#
# Earaindir Rithralas
#
# Hilad Fioldor
#
# Delanduil Rithralas
#
# Urarion Elrebrimir
#
# Elrebrimir Fioldor
#
# Eowul Fioldor
#
# Beladrieng Anaramir
#
# Urarion Eowul
#
# Earaindir Sanakil
#
# Delanduil Isilmalad
#
# Earylas Isilmalad
#
# Rithralas Sanakil
#
# Unithral Elrebrimir
#
# Earylas Eowul
#
# Beladrieng Hilad
#
# Isilmalad Sanakil
#
# Unithral Earylas
#
# Earaindir Anaramir
#
# Unithral Beladrieng
#
# Hilad Anaramir
#
# Delanduil Urarion
#
# Sortie
#
# Delanduil
#
# Dans cet exemple, vous identifiez ainsi que les lettres correspondent aux temples suivants :
#
#
# A -> Delanduil
#
# B -> Unithral
#
# C -> Beladrieng
#
# D -> Hilad
#
# E -> Earaindir
#
# F -> Urarion
#
# G -> Anaramir
#
# H -> Earylas
#
# I -> Eowul
#
# J -> Isilmalad
#
# K -> Elrebrimir
#
# L -> Fioldor
#
# M -> Rithralas
#
# N -> Sanakil
#
# Le temple perdu, identifié ici par la lettre A correspond donc à Delanduil.

# %% [markdown]
# ## **Données**
#
# *Accès aux données*

# %%
import csv
filedir = ('https://cours.unilasalle.fr/courses/SG4007/document/Exercices_Python/Vieille_carte/')

import ssl
ssl._create_default_https_context = ssl._create_unverified_context

import urllib.request

for x in range(1,11):
  f = urllib.request.urlopen(str(filedir+"input"+str(x)+".txt"))

  data=[]
  for i in f:
      line=i.decode('utf-8').strip()
      data.append(line)
  print('Entrée',x,':',data)

  f = urllib.request.urlopen(str(filedir+"output"+str(x)+".txt"))
  for i in f:
      line=i.decode('utf-8').strip()
  print('Sortie',x,':',line,'\n')
# Out:
# Entrée 1 : ['F', 'Lamebring Sanakil', 'Lamithralas Clingoniel', 'Earylas Clingoniel', 'Tunhaad Uriolad', 'Maethoraran Iseldur', 'Rithralas Maethoraran', 'Iseldur Mebrimir', 'Maethoraran Horil', 'Uriolad Fioldor', 'Lamebring Tunhaad', 'Earylas Earaindir', 'Earylas Fioldor', 'Sanakil Lamithralas', 'Tunhaad Fioldor', 'Horil Mebrimir', 'Sanakil Horil', 'Uriolad Mebrimir', 'Earaindir Clingoniel', 'Rithralas Lamithralas', 'Lamebring Iseldur', 'Rithralas Earaindir']
# Sortie 1 : Maethoraran
#
# Entrée 2 : ['G', 'Ralith Uriolad', 'Esesrait Ralith', 'Mebrimir Esesrait', 'Lamebring Eowul', 'Gadrieng Uriolad', 'Rithralas Uriolad', 'Rithralas Gadrieng', 'Maethoraran Eowul', 'Elil Ralith', 'Clingoniel Nilad', 'Mebrimir Maethoraran', 'Mebrimir Nilad', 'Elil Gadrieng', 'Maethoraran Lamebring', 'Nilad Siorion', 'Elil Clingoniel', 'Lamebring Siorion', 'Jaelen Siorion', 'Rithralas Eowul', 'Esesrait Jaelen', 'Clingoniel Jaelen']
# Sortie 2 : Eowul
#
# Entrée 3 : ['J', 'Delanduil Uriolad', 'Lerpecg Delulas', 'Urarion Siorion', 'Urarion Gladrieriand', 'Esesrait Tunhaad', 'Lerpecg Siorion', 'Beladrieng Maethoraran', 'Siorion Uriolad', 'Horil Gladrieriand', 'Lamithralas Tunhaad', 'Maethoraran Tunhaad', 'Gladrieriand Uriolad', 'Esesrait Lamithralas', 'Delanduil Galembor', 'Delulas Galembor', 'Beladrieng Urarion', 'Esesrait Galembor', 'Delulas Delanduil', 'Horil Maethoraran', 'Beladrieng Lamithralas', 'Lerpecg Horil']
# Sortie 3 : Maethoraran
#
# Entrée 4 : ['B', 'Tinaindil Galembor', 'Elviondel Celar', 'Beladrieng Horil', 'Horil Sanakil', 'Mebrimir Sanakil', 'Beladrieng Tinaindil', 'Celar Mebrimir', 'Beladrieng Clingoniel', 'Delanduil Sanakil', 'Calur Elrebrimir', 'Calur Rithralas', 'Delanduil Elrebrimir', 'Clingoniel Delanduil', 'Galembor Thrior', 'Rithralas Thrior', 'Calur Thrior', 'Celar Horil', 'Clingoniel Elrebrimir', 'Tinaindil Mebrimir', 'Elviondel Galembor', 'Elviondel Rithralas']
# Sortie 4 : Beladrieng
#
# Entrée 5 : ['G', 'Eowul Anaramir', 'Lamebring Unithral', 'Beladrieng Gladrieriand', 'Elrebrimir Lamithralas', 'Gadrieng Dagda', 'Eowul Gladrieriand', 'Nilad Uradriembor', 'Unithral Gadrieng', 'Unithral Urarion', 'Lamebring Anaramir', 'Lerpecg Dagda', 'Lerpecg Lamithralas', 'Anaramir Gladrieriand', 'Uradriembor Gadrieng', 'Nilad Urarion', 'Elrebrimir Lerpecg', 'Urarion Dagda', 'Lamebring Beladrieng', 'Uradriembor Beladrieng', 'Nilad Elrebrimir', 'Eowul Lamithralas']
# Sortie 5 : Lamithralas
#
# Entrée 6 : ['H', 'Jaelen Hilad', 'Anaramir Hilad', 'Tinaindil Calur', 'Lamithralas Anaramir', 'Uradriembor Lamithralas', 'Iseldur Horil', 'Esesrait Tinaindil', 'Elaraldor Horil', 'Beladrieng Elaraldor', 'Uradriembor Iseldur', 'Urarion Horil', 'Unithral Jaelen', 'Uradriembor Elaraldor', 'Beladrieng Anaramir', 'Unithral Esesrait', 'Unithral Beladrieng', 'Esesrait Calur', 'Lamithralas Jaelen', 'Tinaindil Hilad', 'Urarion Calur', 'Urarion Iseldur']
# Sortie 6 : Beladrieng
#
# Entrée 7 : ['K', 'Mebrimir Urarion', 'Mebrimir Siorion', 'Earaindir Lamebring', 'Elrebrimir Delulas', 'Mebrimir Eowul', 'Siorion Beladrieng', 'Elrebrimir Dagda', 'Lamebring Lerpecg', 'Urarion Dagda', 'Lamebring Maethoraran', 'Dagda Maethoraran', 'Delulas Eowul', 'Urarion Tinaindil', 'Delulas Tinaindil', 'Tinaindil Maethoraran', 'Gadrieng Lerpecg', 'Elrebrimir Earaindir', 'Earaindir Lerpecg', 'Eowul Beladrieng', 'Gadrieng Beladrieng', 'Gadrieng Siorion']
# Sortie 7 : Dagda
#
# Entrée 8 : ['J', 'Eowul Unithral', 'Celar Beladrieng', 'Esesrait Calur', 'Celar Galembor', 'Siorion Delanduil', 'Siorion Beladrieng', 'Eowul Urarion', 'Uradriembor Delulas', 'Delulas Mebrimir', 'Unithral Beladrieng', 'Dagda Galembor', 'Calur Urarion', 'Esesrait Delanduil', 'Esesrait Delulas', 'Unithral Celar', 'Uradriembor Dagda', 'Delanduil Mebrimir', 'Siorion Mebrimir', 'Eowul Uradriembor', 'Calur Dagda', 'Urarion Galembor']
# Sortie 8 : Delulas
#
# Entrée 9 : ['M', 'Iseldur Tunhaad', 'Elaraldor Rithralas', 'Anaramir Gadrieng', 'Rithralas Hilad', 'Sanakil Elaraldor', 'Siorion Rithralas', 'Earilmand Tunhaad', 'Fioldor Hilad', 'Galembor Gadrieng', 'Sanakil Fioldor', 'Tinaindil Gadrieng', 'Lamithralas Anaramir', 'Galembor Tunhaad', 'Iseldur Earilmand', 'Earilmand Hilad', 'Siorion Fioldor', 'Galembor Anaramir', 'Sanakil Iseldur', 'Lamithralas Siorion', 'Lamithralas Tinaindil', 'Elaraldor Tinaindil']
# Sortie 9 : Anaramir
#
# Entrée 10 : ['I', 'Urarion Ralith', 'Jaelen Tunhaad', 'Clingoniel Thrior', 'Jaelen Uradriembor', 'Uradriembor Ralith', 'Hilad Unithral', 'Uriolad Anaramir', 'Urarion Thrior', 'Tunhaad Ralith', 'Uriolad Clingoniel', 'Anaramir Earylas', 'Celar Jaelen', 'Anaramir Tunhaad', 'Maethoraran Unithral', 'Clingoniel Urarion', 'Celar Maethoraran', 'Celar Earylas', 'Hilad Maethoraran', 'Hilad Thrior', 'Uriolad Uradriembor', 'Earylas Unithral']
# Sortie 10 : Tunhaad
